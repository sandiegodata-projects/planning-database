# %% [markdown]
# # Exploratory Data Analysis
#
# When placed in Metapack data package, this notebook will load the package and run a variety of common EDA operations on the first resource.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')

# %%
pkg = mp.jupyter.open_package()

# For testing and development
#pkg = mp.open_package('http://s3.amazonaws.com/library.metatab.org/cde.ca.gov-accountability_dashboard-2.zip')

pkg
# Out:
# <h1>San Diego Planning Database</h1>
# <p><code>sandiegodata.org-planning-1</code> Last Update: 2018-12-15T00:56:46</p>
# <p>__</p>
# <h2>Contacts</h2>
# <ul>
# <li><strong>Wrangler</strong> <a href="mailto:eric@civicknowledge.com">Eric Busboom</a>, <a href="http://civicknowledge.com">Civic Knowledge</a></li>
# </ul>
# <h2>Resources</h2>
# <ul>
# <li><strong> <a href="data/tracts.csv">tracts</a></strong>. Tract information</li>
# <li><strong> <a href="data/tract_communities.csv">tract_communities</a></strong>. Link tracts to communities and cities</li>
# <li><strong> <a href="data/tract_boundaries.csv">tract_boundaries</a></strong>. Geographic boundaries for tracts</li>
# <li><strong> <a href="data/community_boundaries.csv">community_boundaries</a></strong>. Geographic boundaries for communities and cities</li>
# <li><strong> <a href="data/tract_diabetes.csv">tract_diabetes</a></strong>. </li>
# <li><strong> <a href="data/hpi.csv">hpi</a></strong>. Healthy places index</li>
# <li><strong> <a href="data/business_sites.csv">business_sites</a></strong>. Point locations for businesses</li>
# <li><strong> <a href="data/business_tract_counts.csv">business_tract_counts</a></strong>. Business counts linked to tracts</li>
# <li><strong> <a href="data/acs_pdb.csv">acs_pdb</a></strong>. Planning database for tracts in SD County, ACS columns</li>
# <li><strong> <a href="data/cen10_pdb.csv">cen10_pdb</a></strong>. Planning database for tracts in SD County, Census 2010 columns</li>
# </ul>
# <h2>References</h2>
# <ul>
# <li><strong><a href="metapack+http://library.metatab.org/sandiegodata.org-planning-tracts-8.csv#planning_db_sd">planning_db_sd</a></strong>. San Diego county planning database tracts</li>
# </ul>

# %%
resource_name='hpi'

# %%
pkg.resource(resource_name)
# Out:
# <Resource: metadata.csv 33:1 root.datafile data/hpi.csv ['hpi', 'Healthy places index', '', '', '']>

# %%
df = pkg.resource(resource_name).read_csv(parse_dates=True)

# %%
df.head()
# Out:
#                 geoid  pop2010  pct2010gq     city      zip  county_fips  \
# 0  14000US06001400100     2937        0.1  Oakland  94704.0         6001
# 1  14000US06001400200     1974        3.5  Oakland  94618.0         6001
# 2  14000US06001400300     4865        0.8  Oakland  94618.0         6001
# 3  14000US06001400400     3703        0.9  Oakland  94609.0         6001
# 4  14000US06001400500     3517        3.6  Oakland  94609.0         6001
#
#   county_name   urbantype  hpi2score  hpi2_pctile_pos     ...      leb_pctile  \
# 0     Alameda  urban_area   1.182028        99.114590     ...       96.663673
# 1     Alameda  urban_area   1.325874        99.704863     ...       96.612344
# 2     Alameda  urban_area   0.925666        95.932247     ...       95.136661
# 3     Alameda  urban_area   1.117603        98.537149     ...       68.959322
# 4     Alameda  urban_area   0.562799        83.318363     ...       38.855383
#
#    white_pct  black_pct  asian_pct  latino_pct  multiple_pct  nativeam_pct  \
# 0  71.605789   4.824259  15.713301    4.031702      3.824948           0.0
# 1  83.884970   0.000000   7.921867    8.193163      0.000000           0.0
# 2  67.384106  10.596026   8.671358    8.257450      5.091060           0.0
# 3  66.031054  12.203759   7.354944    9.043857      5.366385           0.0
# 4  51.180196  26.856649   5.987334    9.786989      6.188831           0.0
#
#    pacificisl_pct  other_pct     version
# 0             0.0          0  Wed13Dec17
# 1             0.0          0  Wed13Dec17
# 2             0.0          0  Wed13Dec17
# 3             0.0          0  Wed13Dec17
# 4             0.0          0  Wed13Dec17
#
# [5 rows x 91 columns]

# %%
empty_col_names = [cn for cn in df.columns if df[cn].nunique() == 0]
const_col_names= [cn for cn in df.columns if df[cn].nunique() == 1]
ignore_cols = empty_col_names+const_col_names
dt_col_names= list(df.select_dtypes(include=[np.datetime64]).columns)

number_col_names = [ cn for cn in df.select_dtypes(include=[np.number]).columns if cn not in ignore_cols ]
other_col_names = [cn for cn in df.columns if cn not in (empty_col_names+const_col_names+dt_col_names+number_col_names)]

# %%
pd.DataFrame.from_dict({'empty':[len(empty_col_names)], 
                        'const':[len(const_col_names)],
                        'datetime':[len(dt_col_names)],
                        'number':[len(number_col_names)],
                        'other':[len(other_col_names)],
                       }, 
                       orient='index', columns=['count'])
# Out:
#           count
# empty         0
# const         1
# datetime      0
# number       85
# other         5

# %% [markdown]
# # Constant Columns

# %%
if const_col_names:
    display(df[const_col_names].drop_duplicates().T)
# Out:
#                   0
# version  Wed13Dec17

# %% [markdown]
# # Empty Columns

# %%
if empty_col_names:
    display(df[empty_col_names].drop_duplicates().T)

# %% [markdown]
# # Date and Time Columns

# %%
if dt_col_names:
    display(df[dt_col_names].info())
    display(df[dt_col_names].describe().T)

# %% [markdown]
# # Number Columns

# %%
if number_col_names:
    display(df[number_col_names].info())
    display(df[number_col_names].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8057 entries, 0 to 8056
# Data columns (total 85 columns):
# pop2010                    8057 non-null int64
# pct2010gq                  8024 non-null float64
# zip                        8035 non-null float64
# county_fips                8057 non-null int64
# hpi2score                  7793 non-null float64
# hpi2_pctile_pos            7793 non-null float64
# hpi2_pctile_neg            7793 non-null float64
# quintiles                  7793 non-null float64
# quartiles                  7793 non-null float64
# economic                   7793 non-null float64
# economic_pctile            7793 non-null float64
# education                  7793 non-null float64
# education_pctile           7793 non-null float64
# housing                    7793 non-null float64
# houseing_pctile            7793 non-null float64
# healthcareaccess           7793 non-null float64
# healthcareaccess_pctile    7793 non-null float64
# neighborhood               7793 non-null float64
# neighborhood_pctile        7793 non-null float64
# pollution                  7793 non-null float64
# pollution_pctile           7793 non-null float64
# transportation             7793 non-null float64
# transportation_pctile      7793 non-null float64
# social                     7793 non-null float64
# social_pctile              7793 non-null float64
# insured                    7793 non-null float64
# insured_pctile             7793 non-null float64
# uncrowded                  7793 non-null float64
# uncrowded_pctile           7793 non-null float64
# homeownership              7793 non-null float64
# homeownership_pctile       7793 non-null float64
# automobile                 7793 non-null float64
# automobile_pctile          7793 non-null float64
# commute                    7793 non-null float64
# commute_pctile             7793 non-null float64
# inpreschool                7793 non-null float64
# inpreschool_pctile         7793 non-null float64
# inhighschool               7793 non-null float64
# inhighschool_pctile        7793 non-null float64
# bachelorsed                7793 non-null float64
# bachelorsed_pctile         7793 non-null float64
# employed                   7793 non-null float64
# employed_pctile            7793 non-null float64
# abovepoverty               7793 non-null float64
# abovepoverty_pctile        7793 non-null float64
# income                     7793 non-null float64
# income_pctile              7793 non-null float64
# retail                     7793 non-null float64
# retail_pctile              7793 non-null float64
# parkaccess                 7793 non-null float64
# parkaccess_pctile          7793 non-null float64
# treecanopy                 7793 non-null float64
# treecanopy_pctile          7793 non-null float64
# alcoffsale                 7793 non-null float64
# alcoffsale_pctile          7793 non-null float64
# voting                     7793 non-null float64
# voting_pctile              7793 non-null float64
# ownsevere                  7793 non-null float64
# ownsevere_pctile           7793 non-null float64
# rentsevere                 7793 non-null float64
# rentsevere_pctile          7793 non-null float64
# houserepair                7793 non-null float64
# houserepair_pctile         7793 non-null float64
# twoparents                 7793 non-null float64
# twoparents_pctile          7793 non-null float64
# supermkts                  7793 non-null float64
# supermkts_pctile           7793 non-null float64
# ozone                      7793 non-null float64
# ozone_pctile               7793 non-null float64
# pm25                       7793 non-null float64
# pm25_pctile                7793 non-null float64
# dieselpm                   7793 non-null float64
# dieselpm_pctile            7793 non-null float64
# h20contam                  7793 non-null float64
# h20contam_pctile           7793 non-null float64
# leb                        7793 non-null float64
# leb_pctile                 7793 non-null float64
# white_pct                  8057 non-null float64
# black_pct                  8057 non-null float64
# asian_pct                  8057 non-null float64
# latino_pct                 8057 non-null float64
# multiple_pct               8057 non-null float64
# nativeam_pct               8057 non-null float64
# pacificisl_pct             8057 non-null float64
# other_pct                  8057 non-null int64
# dtypes: float64(82), int64(3)
# memory usage: 5.2 MB
# None
#                           count          mean          std          min  \
# pop2010                  8057.0  4.623800e+03  1984.696591     0.000000
# pct2010gq                8024.0  2.307515e+00     9.574740     0.000000
# zip                      8035.0  9.283661e+04  3445.164575    32.000000
# county_fips              8057.0  6.054691e+03    26.609992  6001.000000
# hpi2score                7793.0  2.438093e-12     0.548753    -1.994633
# hpi2_pctile_pos          7793.0  5.000642e+01    28.869366     0.012832
# hpi2_pctile_neg          7793.0  4.999358e+01    28.869366     0.000000
# quintiles                7793.0  3.000000e+00     1.414123     1.000000
# quartiles                7793.0  2.500064e+00     1.118048     1.000000
# economic                 7793.0  5.646099e-12     0.870467    -2.772752
# economic_pctile          7793.0  5.000642e+01    28.869366     0.012832
# education                7793.0  1.411528e-12     0.682576    -4.727192
# education_pctile         7793.0  5.000611e+01    28.869144     0.012832
# housing                  7793.0 -1.283204e-12     0.649173    -6.071828
# houseing_pctile          7793.0  5.000642e+01    28.869366     0.012832
# healthcareaccess         7793.0  1.283189e-13     1.000000    -4.551007
# healthcareaccess_pctile  7793.0  5.000317e+01    28.869258     0.012832
# neighborhood             7793.0 -1.411521e-12     0.387154    -1.161717
# neighborhood_pctile      7793.0  5.000642e+01    28.869366     0.012832
# pollution                7793.0  1.013733e-11     0.633420    -3.431559
# pollution_pctile         7793.0  5.000584e+01    28.869435     0.012832
# transportation           7793.0  2.309767e-12     0.369664    -2.786433
# transportation_pctile    7793.0  5.000635e+01    28.869398     0.012832
# social                   7793.0  1.154870e-12     0.829758    -3.421043
# social_pctile            7793.0  5.000642e+01    28.869366     0.012832
# insured                  7793.0  7.940862e+01    12.131079    24.200000
# insured_pctile           7793.0  5.000317e+01    28.869258     0.012832
# uncrowded                7793.0  9.069858e+01     9.805062    29.600000
# uncrowded_pctile         7793.0  5.000310e+01    28.865514     0.012832
# homeownership            7793.0  5.433784e+01    23.564124     0.000000
# ...                         ...           ...          ...          ...
# voting                   7793.0  6.771199e+01    10.869562    19.559846
# voting_pctile            7793.0  5.000642e+01    28.869366     0.012832
# ownsevere                7793.0  1.332307e+01     8.615520     0.000000
# ownsevere_pctile         7793.0  5.000400e+01    28.869376     0.076992
# rentsevere               7793.0  2.628857e+01    11.563002     0.000000
# rentsevere_pctile        7793.0  5.000399e+01    28.869253     0.012832
# houserepair              7793.0  9.864787e+01     2.319737    55.353075
# houserepair_pctile       7793.0  5.000235e+01    28.040426     0.012832
# twoparents               7793.0  7.642080e+01    12.942265     0.000000
# twoparents_pctile        7793.0  5.000609e+01    28.869308     0.025664
# supermkts                7793.0  4.974729e+01    35.983316     0.000000
# supermkts_pctile         7793.0  5.000642e+01    28.845761     2.399589
# ozone                    7793.0  4.743097e-02     0.010272     0.026421
# ozone_pctile             7793.0  4.999688e+01    28.794412     0.885410
# pm25                     7793.0  1.039239e+01     2.580386     1.651081
# pm25_pctile              7793.0  4.999729e+01    28.766065     0.064160
# dieselpm                 7793.0  1.922506e+01    16.699284     0.021181
# dieselpm_pctile          7793.0  4.999452e+01    28.868945     0.000000
# h20contam                7793.0  4.725352e+02   249.492410     6.919810
# h20contam_pctile         7793.0  4.999486e+01    28.867119     0.000000
# leb                      7793.0  8.090528e+01     3.465141    64.758363
# leb_pctile               7793.0  5.000642e+01    28.869366     0.012832
# white_pct                8057.0  4.237352e+01    28.255650     0.000000
# black_pct                8057.0  5.403638e+00     9.986868     0.000000
# asian_pct                8057.0  1.233037e+01    15.214541     0.000000
# latino_pct               8057.0  3.707489e+01    27.139392     0.000000
# multiple_pct             8057.0  1.867621e+00     1.931196     0.000000
# nativeam_pct             8057.0  1.137737e-01     1.435330     0.000000
# pacificisl_pct           8057.0  5.972692e-02     0.508986     0.000000
# other_pct                8057.0  5.957552e-03     0.155068     0.000000
#
#                                   25%           50%           75%  \
# pop2010                   3350.000000   4409.000000   5651.000000
# pct2010gq                    0.000000      0.300000      1.100000
# zip                      91602.000000  92691.000000  94558.000000
# county_fips               6037.000000   6059.000000   6073.000000
# hpi2score                   -0.409329      0.007771      0.410343
# hpi2_pctile_pos             25.009624     50.006416     75.003208
# hpi2_pctile_neg             24.996792     49.993584     74.990376
# quintiles                    2.000000      3.000000      4.000000
# quartiles                    2.000000      3.000000      3.000000
# economic                    -0.647621      0.027364      0.655630
# economic_pctile             25.009624     50.006416     75.003208
# education                   -0.453270     -0.055114      0.475321
# education_pctile            25.009624     50.006416     75.003208
# housing                     -0.376837      0.094390      0.454896
# houseing_pctile             25.009624     50.006416     75.003208
# healthcareaccess            -0.635444      0.172398      0.782402
# healthcareaccess_pctile     24.932632     49.967920     74.964712
# neighborhood                -0.224645      0.012679      0.200234
# neighborhood_pctile         25.009624     50.006416     75.003208
# pollution                   -0.453155      0.075619      0.458591
# pollution_pctile            25.022456     50.006416     75.003208
# transportation              -0.172906      0.008142      0.152734
# transportation_pctile       25.009624     50.006416     75.003208
# social                      -0.573418      0.049107      0.637238
# social_pctile               25.009624     50.006416     75.003208
# insured                     71.700000     81.500000     88.900000
# insured_pctile              24.932632     49.967920     74.964712
# uncrowded                   86.500000     94.300000     97.800000
# uncrowded_pctile            24.971128     50.160400     74.489927
# homeownership               36.700000     56.900000     73.500000
# ...                               ...           ...           ...
# voting                      59.957036     68.762440     76.004847
# voting_pctile               25.009624     50.006416     75.003208
# ownsevere                    8.040201     11.747851     16.748768
# ownsevere_pctile            24.996792     50.006416     75.003208
# rentsevere                  18.493151     26.130653     33.834586
# rentsevere_pctile           24.996792     50.006416     74.990376
# houserepair                 98.134328     99.350649    100.000000
# houserepair_pctile          25.022456     49.980752     80.816117
# twoparents                  68.817204     77.932961     85.926223
# twoparents_pctile           25.009624     50.006416     75.003208
# supermkts                   15.403463     48.997602     84.675025
# supermkts_pctile            25.009624     50.006416     75.003208
# ozone                        0.040127      0.046178      0.055122
# ozone_pctile                23.970230     53.278583     75.811626
# pm25                         8.697944     10.370000     12.050000
# pm25_pctile                 24.688823     52.380341     74.759399
# dieselpm                     9.026491     16.560000     24.609648
# dieselpm_pctile             24.996792     49.993584     74.977544
# h20contam                  249.617651    479.227886    664.069078
# h20contam_pctile            23.585269     49.980752     74.990376
# leb                         78.697686     81.063097     83.236109
# leb_pctile                  25.009624     50.006416     75.003208
# white_pct                   16.434540     41.959092     67.023227
# black_pct                    0.000000      2.119832      6.250896
# asian_pct                    2.379571      7.194917     15.947863
# latino_pct                  14.285714     29.019413     56.609485
# multiple_pct                 0.000000      2.011450      3.484428
# nativeam_pct                 0.000000      0.000000      0.000000
# pacificisl_pct               0.000000      0.000000      0.000000
# other_pct                    0.000000      0.000000      0.000000
#
#                                   max
# pop2010                  37452.000000
# pct2010gq                  100.000000
# zip                      96161.000000
# county_fips               6115.000000
# hpi2score                    1.532227
# hpi2_pctile_pos            100.000000
# hpi2_pctile_neg             99.987168
# quintiles                    5.000000
# quartiles                    4.000000
# economic                     2.453069
# economic_pctile            100.000000
# education                    1.696938
# education_pctile           100.000000
# housing                      1.363530
# houseing_pctile            100.000000
# healthcareaccess             1.697407
# healthcareaccess_pctile     99.974336
# neighborhood                 8.350715
# neighborhood_pctile        100.000000
# pollution                    1.568937
# pollution_pctile           100.000000
# transportation               2.053622
# transportation_pctile      100.000000
# social                       2.129654
# social_pctile              100.000000
# insured                    100.000000
# insured_pctile              99.974336
# uncrowded                  100.000000
# uncrowded_pctile            96.933145
# homeownership               98.700000
# ...                               ...
# voting                      94.715657
# voting_pctile              100.000000
# ownsevere                  100.000000
# ownsevere_pctile            99.127422
# rentsevere                  80.000000
# rentsevere_pctile           99.088926
# houserepair                100.000000
# houserepair_pctile          80.816117
# twoparents                 100.000000
# twoparents_pctile           99.563711
# supermkts                  100.000000
# supermkts_pctile            94.251251
# ozone                        0.067829
# ozone_pctile                99.884512
# pm25                        19.600000
# pm25_pctile                 99.987168
# dieselpm                   253.730796
# dieselpm_pctile             99.987168
# h20contam                 1245.651010
# h20contam_pctile            99.987168
# leb                         89.995435
# leb_pctile                 100.000000
# white_pct                  100.000000
# black_pct                  100.000000
# asian_pct                   92.535885
# latino_pct                 100.000000
# multiple_pct                10.083082
# nativeam_pct                78.811881
# pacificisl_pct              14.262604
# other_pct                    7.000000
#
# [85 rows x 8 columns]

# %% [markdown]
# ## Distributions

# %%
def plot_histograms(df):

    col_names = list(df.columns)

    n_cols = np.ceil(np.sqrt(len(col_names)))
    n_rows = np.ceil(np.sqrt(len(col_names)))

    #plt.figure(figsize=(3*n_cols,3*n_rows))
    fig, ax = plt.subplots(figsize=(3*n_cols,3*n_rows))
    
    for i in range(0,len(col_names)):
        plt.subplot(n_rows + 1,n_cols,i+1)
        try:
            g = sns.distplot(df[col_names[i]].dropna(),kde=True) 
            g.set(xticklabels=[])
            g.set(yticklabels=[])
        except:
            pass
        
    plt.tight_layout()

# %%
plot_histograms(df[number_col_names])
# Out:
# /Users/eric/proj/virt/planning/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
[ c for c in number_col_names if 'pctile' not in c ]
# Out:
# ['pop2010',
#  'pct2010gq',
#  'zip',
#  'county_fips',
#  'hpi2score',
#  'quintiles',
#  'quartiles',
#  'economic',
#  'education',
#  'housing',
#  'healthcareaccess',
#  'neighborhood',
#  'pollution',
#  'transportation',
#  'social',
#  'insured',
#  'uncrowded',
#  'homeownership',
#  'automobile',
#  'commute',
#  'inpreschool',
#  'inhighschool',
#  'bachelorsed',
#  'employed',
#  'abovepoverty',
#  'income',
#  'retail',
#  'parkaccess',
#  'treecanopy',
#  'alcoffsale',
#  'voting',
#  'ownsevere',
#  'rentsevere',
#  'houserepair',
#  'twoparents',
#  'supermkts',
#  'ozone',
#  'pm25',
#  'dieselpm',
#  'h20contam',
#  'leb',
#  'white_pct',
#  'black_pct',
#  'asian_pct',
#  'latino_pct',
#  'multiple_pct',
#  'nativeam_pct',
#  'pacificisl_pct',
#  'other_pct']

# %% [markdown]
# ## Box Plots

# %%
def plot_boxes(df):

    col_names = list(df.columns)

    n_cols = np.ceil(np.sqrt(len(col_names)))
    n_rows = np.ceil(np.sqrt(len(col_names)))

    #plt.figure(figsize=(2*n_cols,3*n_rows))
    fig, ax = plt.subplots(figsize=(2*n_cols,5*n_rows))
    
    for i in range(0,len(col_names)):
        plt.subplot(n_rows + 1,n_cols,i+1)
        try:
            g = sns.boxplot(df[col_names[i]].dropna(),orient='v') 
        except:
            pass
        
    plt.tight_layout()

# %%
  
plot_boxes(df[number_col_names])

# %%
## Correlations

# %%
cm = df[number_col_names].corr()

mask = np.zeros_like(cm, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(.5*len(number_col_names),.5*len(number_col_names)))
sns.heatmap(cm, mask=mask, cmap = 'viridis')

# %% [markdown]
# # Other Columns

# %%
if other_col_names:
    display(df[other_col_names].info())
    display(df[other_col_names].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8057 entries, 0 to 8056
# Data columns (total 5 columns):
# geoid           8057 non-null object
# city            6972 non-null object
# county_name     8057 non-null object
# urbantype       8057 non-null object
# hpi_top25pct    7793 non-null object
# dtypes: object(5)
# memory usage: 314.8+ KB
# None
#              count unique                 top  freq
# geoid         8057   8057  14000US06071010015     1
# city          6972    725         Los Angeles   999
# county_name   8057     58         Los Angeles  2346
# urbantype     8057      4          urban_area  7195
# hpi_top25pct  7793      2                  No  5844

# %% [markdown]
# # Nulls

# %%
cols = dt_col_names + number_col_names + other_col_names

fig, ax = plt.subplots(figsize=(15,.5*len(cols)))
sns.heatmap(df[cols].isnull().T,cbar=False,xticklabels=False,cmap = 'viridis', ax=ax )
