# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# <h1>California Unemployment</h1>
# <p><code>bls.gov-laus-ca-1</code> Last Update: 2019-01-03T03:07:40</p>
# <p><em>BLS employment measures for California</em></p>
# <p>This file is a conversion of the BLS Local Area Unemployment (LAUS) file for California. The conversion breaks out parts of the series_id code, and includes a Census ACS geoid for most areas. </p>
# <h2>Local Area Unemployment Statistics Series Identifier</h2>
# <p>The following is a sample format description of the Local Area Unemployment Statistics' series identifier:</p>
# <pre><code>                      1         2
#              12345678901234567890
# Series ID    LAUCN281070000000003
# Positions    Value            Field Name
# 1-2          LA               Prefix
# 3            U                [Seasonal Adjustment Code](https://www.bls.gov/help/hlpseas.htm)
# 4-18         CN2810700000000  [Area Code](https://www.bls.gov/help/def/la.htm#area)
# ...

# %%
df = pkg.resource('laus_ca').dataframe()
df.head()
# Out:
#    year  month  is_ann_avg period      geoid stusab  county census_region  \
# 0  1976      1           0    M01  04000US06     CA     NaN         state
# 1  1976      2           0    M02  04000US06     CA     NaN         state
# 2  1976      3           0    M03  04000US06     CA     NaN         state
# 3  1976      4           0    M04  04000US06     CA     NaN         state
# 4  1976      5           0    M05  04000US06     CA     NaN         state
#
#               series_id sa_code        area_code  measure_code  value  \
# 0  LASBS060000000000003       S  BS0600000000000             3    9.2
# 1  LASBS060000000000003       S  BS0600000000000             3    9.2
# 2  LASBS060000000000003       S  BS0600000000000             3    9.2
# 3  LASBS060000000000003       S  BS0600000000000             3    9.1
# 4  LASBS060000000000003       S  BS0600000000000             3    9.1
#
#   footnote_codes
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
df[['county','census_region']].drop_duplicates()
# Out:
#         county census_region
# 0          NaN         state
# 2060       NaN           NaN
# 8408      19.0           csa
# 9904      71.0           csa
# 11400     47.0           csa
# 12896     89.0           csa
# 14392     61.0           csa
# 15888      1.0           csa
# 17384    107.0           csa
# 18880      1.0        county
# 20376      3.0        county
# 21872      5.0        county
# 23368      7.0        county
# 24864      9.0        county
# 26360     11.0        county
# 27856     13.0        county
# 29352     15.0        county
# 30848     17.0        county
# 32344     19.0        county
# 33840     21.0        county
# 35336     23.0        county
# 36832     25.0        county
# 38328     27.0        county
# 39824     29.0        county
# 41320     31.0        county
# 42816     33.0        county
# 44312     35.0        county
# 45808     37.0        county
# 47308     39.0        county
# 48804     41.0        county
# ...        ...           ...
# ...

# %%
df[(df.measure_code == 3) & (df.county == 73)].value.hist()

# %%
df[(df.measure_code == 3) & (df.county == 73)].value.describe()
# Out:
# count    6732.000000
# mean        6.032204
# std         2.776113
# min         1.600000
# 25%         4.000000
# 50%         5.300000
# 75%         7.500000
# max        19.200000
# Name: value, dtype: float64

# %%
ri = pd.read_csv('/Users/eric/proj/virt-proj/planning/planning-database/datasets/sandiegodata.org-rasp/data/race_iterations.csv')
ri
# Out:
#   code  raceeth                                        description
# 0   A     white                                       White Alone
# 1   B     black                   Black or African American Alone
# 2   C      aian           American Indian and Alaska Native Alone
# 3   D     asian                                       Asian Alone
# 4   E     nhopi  Native Hawaiian and Other Pacific Islander Alone
# 5   F     other                             Some Other Race Alone
# 6   G      many                                 Two or More Races
# 7   H   nhwhite               White Alone, Not Hispanic or Latino
# 8   I      hisp                                Hispanic or Latino
# 9  NaN      all                                          All races

# %%
ri.to_records()
# Out:
# rec.array([(0, 'A ', 'white', 'White Alone '),
#            (1, 'B ', 'black', 'Black or African American Alone '),
#            (2, 'C ', 'aian', 'American Indian and Alaska Native Alone '),
#            (3, 'D ', 'asian', 'Asian Alone '),
#            (4, 'E ', 'nhopi', 'Native Hawaiian and Other Pacific Islander Alone '),
#            (5, 'F ', 'other', 'Some Other Race Alone '),
#            (6, 'G ', 'many', 'Two or More Races '),
#            (7, 'H ', 'nhwhite', 'White Alone, Not Hispanic or Latino '),
#            (8, 'I ', 'hisp', 'Hispanic or Latino '),
#            (9, nan, 'all', 'All races')],
#           dtype=[('index', '<i8'), ('code', 'O'), ('raceeth', 'O'), ('description', 'O')])
